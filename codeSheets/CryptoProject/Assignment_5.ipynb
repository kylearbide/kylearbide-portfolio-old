# %%
import pandas as pd

# %% [markdown]
# Take 10 candidates and find what packs commited to them and where those packs are located.
# FEC Dataset
# Also merge practice files from w3

# %%
HCrime = pd.read_csv("hate_crime.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
HCrime.head()
# Out:
#    INCIDENT_ID  DATA_YEAR  ... MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0         3015       1991  ...                S             S
# 1         3016       1991  ...                S             S
# 2           43       1991  ...                S             S
# 3           44       1991  ...                M             S
# 4         3017       1991  ...                S             S
#
# [5 rows x 28 columns]

# %%
HCrime.describe()
# Out:
#         INCIDENT_ID      DATA_YEAR  ...   VICTIM_COUNT  TOTAL_INDIVIDUAL_VICTIMS
# count  2.190730e+05  219073.000000  ...  219073.000000             215594.000000
# mean   2.053502e+05    2005.439269  ...       1.247648                  0.984587
# std    3.206649e+05       8.573008  ...       2.276537                  1.174243
# min    2.000000e+00    1991.000000  ...       1.000000                  0.000000
# 25%    5.477000e+04    1998.000000  ...       1.000000                  1.000000
# 50%    1.095380e+05    2005.000000  ...       1.000000                  1.000000
# 75%    1.643070e+05    2013.000000  ...       1.000000                  1.000000
# max    1.357330e+06    2020.000000  ...     900.000000                147.000000
#
# [8 rows x 9 columns]

# %%
zips = pd.read_json("us-zips.json")

# %%
zips.head()
# Out:
#                             datasetid  ...               record_timestamp
# 0  us-zip-code-latitude-and-longitude  ...  2018-02-09T11:33:38.603-05:00
# 1  us-zip-code-latitude-and-longitude  ...  2018-02-09T11:33:38.603-05:00
# 2  us-zip-code-latitude-and-longitude  ...  2018-02-09T11:33:38.603-05:00
# 3  us-zip-code-latitude-and-longitude  ...  2018-02-09T11:33:38.603-05:00
# 4  us-zip-code-latitude-and-longitude  ...  2018-02-09T11:33:38.603-05:00
#
# [5 rows x 5 columns]

# %%
zips.fields.count()
# Out:
# 43191

# %%
candidates = pd.read_csv("ccl.txt", sep="|", header=None)
c_headers = pd.read_csv("ccl_header_file.csv")

# %%
c_headers = list(c_headers.columns.values)
candidates.columns = c_headers

# %%
candidates.head()
# Out:
#      CAND_ID  CAND_ELECTION_YR  FEC_ELECTION_YR  ... CMTE_TP CMTE_DSGN LINKAGE_ID
# 0  C00713602              2019             2020  ...       O         U     228963
# 1  H0AK00105              2020             2020  ...       H         P     229250
# 2  H0AL01055              2020             2020  ...       H         P     226125
# 3  H0AL01063              2020             2020  ...       H         P     227053
# 4  H0AL01071              2020             2020  ...       H         P     227054
#
# [5 rows x 7 columns]

# %%
candidates.dtypes
# Out:
# CAND_ID             object
# CAND_ELECTION_YR     int64
# FEC_ELECTION_YR      int64
# CMTE_ID             object
# CMTE_TP             object
# CMTE_DSGN           object
# LINKAGE_ID           int64
# dtype: object

# %%
cms = pd.read_csv("cm.txt", sep="|", header=None)
cm_headers = pd.read_csv("cm_header_file.csv")

# %%
cm_headers = list(cm_headers.columns.values)
cms.columns = cm_headers

# %%
cms.head()
# Out:
#      CMTE_ID  ... CAND_ID
# 0  C00000059  ...     NaN
# 1  C00000422  ...     NaN
# 2  C00000489  ...     NaN
# 3  C00000547  ...     NaN
# 4  C00000638  ...     NaN
#
# [5 rows x 15 columns]

# %%
cms.drop(['CAND_ID'], axis = 1, inplace = True)
candidates.drop(['CMTE_DSGN','CMTE_TP'], axis = 1, inplace= True)

# %%
candidates_merged = candidates.merge(cms,on = 'CMTE_ID', how = 'left')

# %%
candidates_merged.head(10)
# Out:
#      CAND_ID  CAND_ELECTION_YR  ...  ORG_TP              CONNECTED_ORG_NM
# 0  C00713602              2019  ...     NaN                           NaN
# 1  H0AK00105              2020  ...     NaN                           NaN
# 2  H0AL01055              2020  ...     NaN  JERRY CARL VICTORY COMMITTEE
# 3  H0AL01063              2020  ...     NaN                          NONE
# 4  H0AL01071              2020  ...     NaN                           NaN
# 5  H0AL01089              2020  ...     NaN                          NONE
# 6  H0AL01097              2020  ...     NaN                           NaN
# 7  H0AL01105              2020  ...     NaN                           NaN
# 8  H0AL01113              2020  ...     NaN                           NaN
# 9  H0AL01121              2020  ...     NaN                          NONE
#
# [10 rows x 18 columns]

# %%
c_names = pd.read_csv("cn.txt", sep="|", header=None)
cn_headers = pd.read_csv("cn_header_file.csv")

# %%
cn_headers = list(cn_headers.columns.values)
c_names.columns = cn_headers

# %%
c_names.head(10)
# Out:
#      CAND_ID                               CAND_NAME  ... CAND_ST  CAND_ZIP
# 0  H0AK00105                            LAMB, THOMAS  ...      AK   99654.0
# 1  H0AK00113                       TUGATUK, RAY SEAN  ...      AK   99628.0
# 2  H0AK01046                        CATALANO, THOMAS  ...      AK   99503.0
# 3  H0AL01055                     CARL, JERRY LEE, JR  ...      AL   36685.0
# 4  H0AL01063            LAMBERT, DOUGLAS WESTLEY III  ...      AL   36527.0
# 5  H0AL01071               PRINGLE, CHRISTOPHER PAUL  ...      AL   36602.0
# 6  H0AL01089                         HIGHTOWER, BILL  ...      AL   36691.0
# 7  H0AL01097                         AVERHART, JAMES  ...      AL   36602.0
# 8  H0AL01105                        GARDNER, KIANI A  ...      AL   36526.0
# 9  H0AL01113  ROMAGNANO, CHASE ANDERSON ANDY REVEREN  ...      FL   32505.0
#
# [10 rows x 15 columns]

# %%
c_names_new = c_names[['CAND_ID','CAND_NAME','CAND_PTY_AFFILIATION','CAND_OFFICE_ST']]

# %%
cand_names_merge = candidates_merged.merge(c_names_new,on = 'CAND_ID', how = 'left')

# %%
cand_names_merge.head(10)
# Out:
#      CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 0  C00713602              2019  ...                   NaN            NaN
# 1  H0AK00105              2020  ...                   NNE             AK
# 2  H0AL01055              2020  ...                   REP             AL
# 3  H0AL01063              2020  ...                   REP             AL
# 4  H0AL01071              2020  ...                   REP             AL
# 5  H0AL01089              2020  ...                   REP             AL
# 6  H0AL01097              2020  ...                   DEM             AL
# 7  H0AL01105              2020  ...                   DEM             AL
# 8  H0AL01113              2020  ...                   REP             AL
# 9  H0AL01121              2020  ...                   REP             AL
#
# [10 rows x 21 columns]

# %%
cand_names_merge.dropna(subset=['CAND_NAME'], inplace = True)

# %%
cand_names_merge.head(10)
# Out:
#       CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 1   H0AK00105              2020  ...                   NNE             AK
# 2   H0AL01055              2020  ...                   REP             AL
# 3   H0AL01063              2020  ...                   REP             AL
# 4   H0AL01071              2020  ...                   REP             AL
# 5   H0AL01089              2020  ...                   REP             AL
# 6   H0AL01097              2020  ...                   DEM             AL
# 7   H0AL01105              2020  ...                   DEM             AL
# 8   H0AL01113              2020  ...                   REP             AL
# 9   H0AL01121              2020  ...                   REP             AL
# 10  H0AL01139              2020  ...                   DEM             AL
#
# [10 rows x 21 columns]

# %%
# Here we are grouping by the locations of the committees and finding how many candidates are in each location 
cands_per_cmtearea = cand_names_merge.groupby(['CMTE_CITY','CMTE_ST']).agg({'CAND_ID': "nunique"})
cands_per_cmtearea
# Out:
#                                     CAND_ID
# CMTE_CITY                  CMTE_ST
# , NEW YORK                 NY             1
# ABILENE                    TX             2
# ABINGDON                   VA             1
# ABQ. EDWARDS PROVINCE. UM. NM             2
# ACME                       MI             1
# ...                                     ...
# ZEELAND                    MI             1
# ZEPHYRHILLS                FL             1
# ZION CROSSROADS            VA             1
# ZIONSVILLE                 IN             2
# ZIRCONIA                   NC             1
#
# [2716 rows x 1 columns]

# %%
cands_per_cmtearea.sort_values(by = 'CAND_ID', ascending = False, inplace = True)
cands_per_cmtearea.head(10)
# The largest number of candidates are followed by committees based out of DC, Alexandria, and Houston
# Out:
#                      CAND_ID
# CMTE_CITY   CMTE_ST
# WASHINGTON  DC           134
# ALEXANDRIA  VA           104
# HOUSTON     TX            87
# BETHESDA    MD            82
# NEW YORK    NY            58
# LAS VEGAS   NV            51
# LOS ANGELES CA            47
# SAN ANTONIO TX            41
# DENVER      CO            39
# DALLAS      TX            36

# %%
#This calculation is very similar except it just located the number of unique committees in each area
cmte_per_cmtearea = cand_names_merge.groupby(['CMTE_CITY','CMTE_ST']).agg({'CMTE_ID': "nunique"})
cmte_per_cmtearea.sort_values(by = 'CMTE_ID', ascending = False, inplace = True)
cmte_per_cmtearea.head(10)
# Out:
#                      CMTE_ID
# CMTE_CITY   CMTE_ST
# WASHINGTON  DC           139
# HOUSTON     TX            86
# ALEXANDRIA  VA            83
# NEW YORK    NY            68
# BETHESDA    MD            60
# LAS VEGAS   NV            52
# LOS ANGELES CA            49
# SAN ANTONIO TX            42
# DENVER      CO            42
# RALEIGH     NC            40

# %%
# im curious how often committee IDs and Candidate IDs are repeated/ if they are repeated.
C_ids = cand_names_merge.CAND_ID.value_counts()
C_ids.head(10)
# Out:
# P60022118    10
# S2FL00441     8
# H8GA04117     8
# P60016888     8
# S4IA00129     7
# S2MT00096     7
# P00015214     6
# S2KY00012     6
# P00011361     6
# S2TX00106     6
# Name: CAND_ID, dtype: int64

# %%
CM_ids = cand_names_merge.CMTE_ID.value_counts()
CM_ids.head(10)
# Out:
# C00701243    16
# C00493783    16
# C00528851    14
# C00685057    13
# C00689471    12
# C00624841    10
# C00567677     8
# C00748749     8
# C00654699     8
# C00590653     8
# Name: CMTE_ID, dtype: int64

# %%
cand_names_merge[cand_names_merge['CAND_ID']== 'P60022118']
# candidate has 10 entries, 4 with different committees and 6 without committees
# I could change the join type to prevent these no committee entries
# Out:
#         CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 5684  P60022118              2016  ...                   CRV             US
# 5685  P60022118              2016  ...                   CRV             US
# 5686  P60022118              2016  ...                   CRV             US
# 5687  P60022118              2016  ...                   CRV             US
# 5688  P60022118              2016  ...                   CRV             US
# 5689  P60022118              2016  ...                   CRV             US
# 5690  P60022118              2016  ...                   CRV             US
# 5691  P60022118              2016  ...                   CRV             US
# 5692  P60022118              2016  ...                   CRV             US
# 5693  P60022118              2016  ...                   CRV             US
#
# [10 rows x 21 columns]

# %%
cand_cmte_merged = candidates.merge(cms,on = 'CMTE_ID', how = 'inner')

# %%
cand_cmte_merged = cand_cmte_merged.merge(c_names_new,on = 'CAND_ID', how = 'left')
cand_cmte_merged.dropna(subset=['CAND_NAME'], inplace = True)

# %%
C_ids2 = cand_cmte_merged.CAND_ID.value_counts()
C_ids2.head(10)
# Out:
# S2FL00441    8
# P60016888    8
# H8GA04117    8
# S2MT00096    7
# S4IA00129    7
# S8MO00160    6
# S2TX00106    6
# S2KY00012    6
# P00011361    6
# S8IN00171    6
# Name: CAND_ID, dtype: int64

# %%
cand_cmte_merged[cand_cmte_merged['CAND_ID']== 'P60022118']
# Out:
#         CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 5616  P60022118              2016  ...                   CRV             US
# 5617  P60022118              2016  ...                   CRV             US
# 5618  P60022118              2016  ...                   CRV             US
# 5619  P60022118              2016  ...                   CRV             US
#
# [4 rows x 21 columns]

# %%
cand_cmte_merged[cand_cmte_merged['CAND_ID']== 'S2FL00441']
# still some duplicate entries exist which leaves questions
# I think I want to eliminate any enties where CAND_ID, CMTE_ID and CAND_ELECTION_YR are Identical
# Out:
#         CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 6145  S2FL00441              2022  ...                   DEM             FL
# 6146  S2FL00441              2022  ...                   DEM             FL
# 6147  S2FL00441              2022  ...                   DEM             FL
# 6148  S2FL00441              2022  ...                   DEM             FL
# 6149  S2FL00441              2022  ...                   DEM             FL
# 6150  S2FL00441              2022  ...                   DEM             FL
# 6151  S2FL00441              2022  ...                   DEM             FL
# 6152  S2FL00441              2022  ...                   DEM             FL
#
# [8 rows x 21 columns]

# %%
unique_combos = cand_cmte_merged.drop_duplicates(subset=["CAND_ID","CMTE_ID",'CAND_ELECTION_YR'])
C_ids2 = unique_combos.CAND_ID.value_counts()
C_ids2.head(10)
# Out:
# S4IA00129    7
# S2MT00096    7
# S8AZ00221    6
# S2TX00106    6
# S8IN00171    6
# S8WV00143    6
# S2KY00012    6
# S8MO00160    6
# P00011361    6
# S8ND00120    5
# Name: CAND_ID, dtype: int64

# %%
cand_cmte_merged[cand_cmte_merged['CAND_ID']== 'S4IA00129']
# now it appears every entry is a unique combo of CMTE CAND and YEAR
# Out:
#         CAND_ID  CAND_ELECTION_YR  ...  CAND_PTY_AFFILIATION CAND_OFFICE_ST
# 2636  S4IA00129              2020  ...                   REP             IA
# 6266  S4IA00129              2020  ...                   REP             IA
# 6267  S4IA00129              2020  ...                   REP             IA
# 6268  S4IA00129              2020  ...                   REP             IA
# 6269  S4IA00129              2020  ...                   REP             IA
# 6270  S4IA00129              2020  ...                   REP             IA
# 6271  S4IA00129              2020  ...                   REP             IA
#
# [7 rows x 21 columns]

# %%
CMTEParties = unique_combos.CMTE_PTY_AFFILIATION.value_counts()
print(CMTEParties.head(10))
CANDParties = unique_combos.CAND_PTY_AFFILIATION.value_counts()
print(CANDParties.head(10))
# Out:
# DEM    2628
# REP    2580
# IND     372
# LIB     161
# NPA      65
# W        64
# GRE      59
# OTH      59
# UN       46
# NNE      45
# Name: CMTE_PTY_AFFILIATION, dtype: int64
# REP    2830
# DEM    2730
# IND     391
# LIB     162
# W        67
# GRE      61
# NPA      60
# OTH      59
# UN       47
# NNE      46
# Name: CAND_PTY_AFFILIATION, dtype: int64

# %%
diffParty = unique_combos[unique_combos['CAND_PTY_AFFILIATION'] != unique_combos['CMTE_PTY_AFFILIATION']]
diffParty.head(10)
diffParty.count()
# 686 times the candidate and committee have different party affiliations
# Out:
# CAND_ID                 686
# CAND_ELECTION_YR        686
# FEC_ELECTION_YR         686
# CMTE_ID                 686
# LINKAGE_ID              686
# CMTE_NM                 686
# TRES_NM                 683
# CMTE_ST1                685
# CMTE_ST2                101
# CMTE_CITY               685
# CMTE_ST                 685
# CMTE_ZIP                685
# CMTE_DSGN               686
# CMTE_TP                 686
# CMTE_PTY_AFFILIATION    306
# CMTE_FILING_FREQ        686
# ORG_TP                    3
# CONNECTED_ORG_NM        290
# CAND_NAME               686
# CAND_PTY_AFFILIATION    679
# CAND_OFFICE_ST          686
# dtype: int64

# %%
CMTEParties = diffParty.CMTE_PTY_AFFILIATION.value_counts()
print(CMTEParties.head(10))
CANDParties = diffParty.CAND_PTY_AFFILIATION.value_counts()
print(CANDParties.head(10))
# Out:
# DEM    50
# IND    48
# REP    46
# OTH    21
# NPA    15
# W      15
# UN     12
# UNK    11
# NNE    10
# DFL     9
# Name: CMTE_PTY_AFFILIATION, dtype: int64
# REP    296
# DEM    152
# IND     67
# UNK     27
# OTH     21
# W       18
# UN      13
# NNE     11
# LIB     10
# NPA     10
# Name: CAND_PTY_AFFILIATION, dtype: int64
